# %% [markdown]
# # Project 2 - Machine Learning Modeling Overview

# %% [markdown]
# ## Selection of dataset
# Chose the Detection of IoT Botnet Attacks N-BaIoT from the UCI Machine Learning Repository:
#
# https://archive.ics.uci.edu/dataset/442/detection+of+iot+botnet+attacks+n+baiot
#
# It is a collection of CSV files per device, each representing benign and attack traffic captured from IoT devices. There is a folder for each device. Inside each are many csv files. Each CSV contains raw feature vectors extracted from traffic windows.

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Background
# A botnet is a network of internet-connected devices (like computers, phones, IoT gadgets) that have been infected with malware and are being controlled remotely by an attacker, often without the owner's knowledge.
#
# Bot = infected device ('robot')
# Net = network
# botnet = a network of infected devices working together
#
# Botnets are used for:
# DDoS attacks - they flood a website until it crashes
# spam campaigns - send millions of phishing emails
# data theft/keylogging - steal login credentials
# crypto mining - use your device to mine crypto
# click fraud - fake ad clicks for revenue
# spreading malware - infect other systems
#
# How botnets work:
# 1. Malware infects a device (eg. via phishing, weak passowrds, open ports)
# 2. device becomes a "zombie" - quietly waits for commands
# 3. all zombie devices are controlled by a command and control (C&C) server
# 4. attacker sends order to launch attacks or harvest data
#
# IoT botnets increasingly target smart devices such as doorbells, cameras, thermostats, and baby monitors, because they often have poor security, making them easy targets.

# %% [markdown]
# ## Dataset Details
# What is the N-BaIoT dataset?
# It’s a benchmark dataset created by researchers to help build and evaluate machine learning models for detecting botnet attacks on Internet of Things (IoT) devices.
#
# Key facts:
# 1. Contains data from 9 IoT devices (eg. doorbell, camera, baby monitor)
# 2. The dataset contains traffic types, including benign and multiple botnet attack types (eg. Mirai, Bashlite)
# 3. Files are CSVs per device, each representing one type of behavior
# 4. Features are pre-extracted statistical features from raw network traffic
# 5. No "Label" columns, but filesnames will indicate if its benign or an attack
#
# Purpose of dataset:
# To support network-based intrusion detection systems that:
# 1. monitor traffic from IoT devices
# 2. detect abnormal patterns linked to botnet activity
# 3. work without needing deep packet inspection (for speed and privacy)

# %% [markdown]
# ## Project goals
# 1. train a binary classifier to detect whether an IoT event is benign or attack
# 2. if there's enough time, train a multi-class classification to identify specific botnet families

# %% [markdown]
# ## Project Considerations
# 1. labeling - no "label" column but file names will indicate benign or attack type
# 2. the data is highly imbalanced. 92% of the data is labeled as attack type, while only 8% is labeled as benign. This is now a severely imbalanced classification problem which can cause models to always predict "attack", and may lead to high accuracy but poor recall on minority class (benign)

# %% [markdown]
# # Data Understanding

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# define function to load data

def load_n_baiot_data(device_dir):
    dataframes = []
    
    # walk through the directory structure
    for root, dirs, files in os.walk(device_dir):
        for f in files:
            if f.endswith('.csv'):
                path = os.path.join(root, f)

                # determine label based on filename
                label = 'benign' if 'benign' in f.lower() else 'attack'
                print(f"Loading: {path} as {label}")
                # read the CSV file
                # use header=0 to read the first row as column names
                df = pd.read_csv(path, header=0, skiprows=0)

                # add label (benign or attack) and source file to the dataframe
                df['label'] = label
                df['source_file'] = f
                dataframes.append(df)

    return pd.concat(dataframes, ignore_index=True)

# define function to load all devices
def load_all_devices(base_dir):
    all_dfs = []

    for device_name in os.listdir(base_dir):
        device_path = os.path.join(base_dir, device_name)
        if os.path.isdir(device_path):
            print(f"Loading: {device_name}")
            df = load_n_baiot_data(device_path)
            df['device'] = device_name
            all_dfs.append(df)

    return pd.concat(all_dfs, ignore_index=True)

# %%
# define the folder where the data is stored

# path for PC
# base_dir = r"C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot"

# path for laptop
base_dir = r
# load all devices data
full_df = load_all_devices(base_dir)
# Out:
# Loading: Danmini_Doorbell
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Danmini_Doorbell\mirai_attacks\udpplain.csv as attack
# Loading: Ecobee_Thermostat
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ecobee_Thermostat\mirai_attacks\udpplain.csv as attack
# Loading: Ennio_Doorbell
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Ennio_Doorbell\gafgyt_attacks\udp.csv as attack
# Loading: Philips_B120N10_Baby_Monitor
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Philips_B120N10_Baby_Monitor\mirai_attacks\udpplain.csv as attack
# Loading: Provision_PT_737E_Security_Camera
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_737E_Security_Camera\mirai_attacks\udpplain.csv as attack
# Loading: Provision_PT_838_Security_Camera
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Provision_PT_838_Security_Camera\mirai_attacks\udpplain.csv as attack
# Loading: Samsung_SNH_1011_N_Webcam
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\Samsung_SNH_1011_N_Webcam\gafgyt_attacks\udp.csv as attack
# Loading: SimpleHome_XCS7_1002_WHT_Security_Camera
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1002_WHT_Security_Camera\mirai_attacks\udpplain.csv as attack
# Loading: SimpleHome_XCS7_1003_WHT_Security_Camera
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\benign_traffic.csv as benign
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\gafgyt_attacks\combo.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\gafgyt_attacks\junk.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\gafgyt_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\gafgyt_attacks\tcp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\gafgyt_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\mirai_attacks\ack.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\mirai_attacks\scan.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\mirai_attacks\syn.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\mirai_attacks\udp.csv as attack
# Loading: C:\Users\jtlee\Documents\Flatiron\data\detection of iot botnet attacks n baiot\SimpleHome_XCS7_1003_WHT_Security_Camera\mirai_attacks\udpplain.csv as attack
# (7062606, 118)
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_weight  \
# 0            0.000000            1.000000  ...           1.000000
# 1            0.000000            1.000000  ...           5.319895
# 2           35.991542            1.996939  ...           6.318264
# 3            0.000000            1.000000  ...           1.000000
# 4        19153.795810            1.992323  ...           1.000000
#
#    HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        60.000000        0.000000             60.000000           0.000000
# 1       344.262695        4.710446            344.262695          22.188299
# 2       347.703087        9.034660            347.703087          81.625077
# 3       337.000000        0.000000            337.000000           0.000000
# 4        60.000000        0.000000             60.000000           0.000000
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc   label         source_file  \
# 0                    0.0             0.0  benign  benign_traffic.csv
# 1                    0.0             0.0  benign  benign_traffic.csv
# 2                    0.0             0.0  benign  benign_traffic.csv
# 3                    0.0             0.0  benign  benign_traffic.csv
# 4                    0.0             0.0  benign  benign_traffic.csv
#
#              device
# 0  Danmini_Doorbell
# 1  Danmini_Doorbell
# 2  Danmini_Doorbell
# 3  Danmini_Doorbell
# 4  Danmini_Doorbell
#
# [5 rows x 118 columns]
# device
# Philips_B120N10_Baby_Monitor                1098677
# Danmini_Doorbell                            1018298
# SimpleHome_XCS7_1002_WHT_Security_Camera     863056
# SimpleHome_XCS7_1003_WHT_Security_Camera     850826
# Provision_PT_838_Security_Camera             836891
# Ecobee_Thermostat                            835876
# Provision_PT_737E_Security_Camera            828260
# Samsung_SNH_1011_N_Webcam                    375222
# Ennio_Doorbell                               355500
# Name: count, dtype: int64
# label
# attack    6506674
# benign     555932
# Name: count, dtype: int64

# %%
print("Full device dataframe shape:\n", full_df.shape)
print("\nFull device dataframe - # of observations:\n", full_df['device'].value_counts())
print("\nFull device dataframe - # of types of observations:\n", full_df['label'].value_counts())
print("\nFull device dataframe - preview:\n", full_df.head())
# Out:
# Full device dataframe shape:
#  (7062606, 118)
#
# Full device dataframe - # of observations:
#  device
# Philips_B120N10_Baby_Monitor                1098677
# Danmini_Doorbell                            1018298
# SimpleHome_XCS7_1002_WHT_Security_Camera     863056
# SimpleHome_XCS7_1003_WHT_Security_Camera     850826
# Provision_PT_838_Security_Camera             836891
# Ecobee_Thermostat                            835876
# Provision_PT_737E_Security_Camera            828260
# Samsung_SNH_1011_N_Webcam                    375222
# Ennio_Doorbell                               355500
# Name: count, dtype: int64
#
# Full device dataframe - # of types of observations:
#  label
# attack    6506674
# benign     555932
# Name: count, dtype: int64
#
# Full device dataframe - preview:
#     MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      354.000000            0.000000          1.000000
# 2          1.857879      360.458980           35.789338          1.912127
# 3          1.000000      337.000000            0.000000          1.000000
# 4          1.680223      172.140917        18487.448750          1.793580
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      354.000000            0.000000          1.000000      354.000000
# 2      360.275733           35.923972          1.969807      360.091968
# 3      337.000000            0.000000          1.000000      337.000000
# 4      182.560279        18928.175300          1.925828      193.165753
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_weight  \
# 0            0.000000            1.000000  ...           1.000000
# 1            0.000000            1.000000  ...           5.319895
# 2           35.991542            1.996939  ...           6.318264
# 3            0.000000            1.000000  ...           1.000000
# 4        19153.795810            1.992323  ...           1.000000
#
#    HpHp_L0.01_mean  HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        60.000000        0.000000             60.000000           0.000000
# 1       344.262695        4.710446            344.262695          22.188299
# 2       347.703087        9.034660            347.703087          81.625077
# 3       337.000000        0.000000            337.000000           0.000000
# 4        60.000000        0.000000             60.000000           0.000000
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc   label         source_file  \
# 0                    0.0             0.0  benign  benign_traffic.csv
# 1                    0.0             0.0  benign  benign_traffic.csv
# 2                    0.0             0.0  benign  benign_traffic.csv
# 3                    0.0             0.0  benign  benign_traffic.csv
# 4                    0.0             0.0  benign  benign_traffic.csv
#
#              device
# 0  Danmini_Doorbell
# 1  Danmini_Doorbell
# 2  Danmini_Doorbell
# 3  Danmini_Doorbell
# 4  Danmini_Doorbell
#
# [5 rows x 118 columns]

# %% [markdown]
# Data is highly imbalanced. Will need to use stratified splits during train_test_split. Use class weights in models like logistic regression, random forest, XGBoost
#
# Cannot rely on accuracy. Will need to use precision, recall, f1-score, ROC-AUC, and confusion matrix

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Statistical Data Analysis

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Conclusion
